# %%
# first find the latest date that was inserted in the climate data into the MongoDB Database in Part A. 
from pprint import pprint
import pymongo
from pymongo import MongoClient
import csv
from datetime import datetime
from datetime import timedelta
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import time

# %%
def samedate(hotspot_date, climate_date):
    # this function checks if two dates are the same
    # This function was made because date is forrmatted differently in hotspot_historic and climate_historic
    # eg. hotspot historic '27/12/2018' and climate historic '27/12/18'
    actual_date = []
    final_date = []
    join_string = ''
    date_length = len(hotspot_date)
    for k in range(date_length - 1, -1, -1):
        if k == 7 or k == 6:
            continue
        else:
            actual_date.append(hotspot_date[k])
    for j in range(date_length - 3, -1, -1):
        final_date.append(actual_date[j])

    return (join_string.join(final_date) == climate_date)

# %%
def get_prec_number(a_string):
    # this function gives the float part of a precipitation measurement
    final = a_string.strip()
    return float(final[0:4])
    

def get_prec_letter(a_string):
    # this function gives the letter representing the tyoe of precipitation measurement
    final = a_string.strip()
    return final[-1]

# %%
def change_format(a_date):
    date_final = datetime.strptime(a_date, '%d/%m/%y')
    formatted = date_final.strftime("20%y/%m/%d")
    return formatted

# %%
# Task 2
# Question 1
# So we have to load all the data from the csv files into a new database fit3182_assignment_db
# Check if the main collection already exists
try:
    a_collection.drop()
except NameError:
    pass
# Now create the data base
client = MongoClient() # so we connect on the default host and port
db = client.fit3182_assignment_db # create a new database fit3182_assignment_db
a_collection = db.climatee # create a new collection called 'a_collection'
with open('climate_historic.csv', 'r') as file_one:  # open climate historic file
    # now create a csv object for each of the files
    climate_data = csv.reader(file_one)
    climate_lines = []
    count = 0
    for c_line in climate_data:
        if count == 0:
            count += 1
        else:
            climate_lines.append(c_line)   # put each line of the data in a list 
            

            
with open('hotspot_historic.csv', 'r') as file_two: # open hotspot historic file
    hotspot_data = csv.reader(file_two)
    hotspot_lines = []
    count = 0
    for h_line in hotspot_data:  # go through the hotspot data.
        if count == 0:
            count += 1
        else:
            hotspot_lines.append(h_line)  # put each line of the data in a list

documents = []
for climate_line in climate_lines:
    matched = False
    for hotspot_line in hotspot_lines:
        if samedate(hotspot_line[4], climate_line[1]):
            new_entry = {
             "latitude" : float(hotspot_line[0]),
             "longitude": float(hotspot_line[1]),
             "datetime" : hotspot_line[2],
             "confidence" : float(hotspot_line[3]),
             "surface_temperature_celsius" : float(hotspot_line[5]),
            "station": float(climate_line[0]),
            "date": change_format(climate_line[1]),
            "air_temperature_celsius" : float(climate_line[2]),
            "relative_humidity": float(climate_line[3]),
            "windspeed_knots" : float(climate_line[4]),
            "max_wind_speed": float(climate_line[5]),
            "precipitation_level": get_prec_number(climate_line[6]),
            "precipitation_type": get_prec_letter(climate_line[6]),
            "GHI_w/m2": float(climate_line[7])}
            documents.append(new_entry)
            matched = True
    if matched == False: # there was not a fire on this date
        # Set None's for all the unmatchable values cause there was no fire on this date
        no_fire = {
            "latitude" : None,
            "longitude": None,
            "datetime" : None,
            "confidence" : None,
            "surface_temperature_celsius": None,
            "station": float(climate_line[0]),
            "date": change_format(climate_line[1]),
            "air_temperature_celsius" : float(climate_line[2]),
            "relative_humidity": float(climate_line[3]),
            "windspeed_knots" : float(climate_line[4]),
            "max_wind_speed": float(climate_line[5]),
            "precipitation_level": get_prec_number(climate_line[6]),
            "precipitation_type": get_prec_letter(climate_line[6]),
            "GHI_w/m2": float(climate_line[7])
        }
        documents.append(no_fire)


result = a_collection.insert_many(documents)  
# cursor = a_collection.find({})
# for item in cursor:
#     pprint(item)

# %%
# find the latest date in the stream
latest_date = a_collection.find().sort("date", pymongo.DESCENDING).limit(1)
for k in latest_date:
    new_date = datetime.strptime(k['date'], '%Y/%m/%d')

# %%
# get the data from the stream now

            
with open('climate_streaming.csv', 'r') as file_three: # open hotspot historic file
    cstream_data = csv.reader(file_three)
    cstream_lines = []
    count = 0
    for line in cstream_data:  # go through the hotspot data.
        if count == 0:
            count += 1
        else:
            cstream_lines.append(line)  # put each line of the data in a list

def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ', data)
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'same_topic'
    prod = 'Producer1'
    print('Publishing records..')
    producer = connect_kafka_producer()
    length_lines = len(cstream_lines)
    
    while True:
        index_of_line = random.randrange(0, length_lines)
        new_date = new_date + timedelta(days = 1)
        str_date = new_date.strftime('%Y/%m/%d')
        line_sent = cstream_lines[index_of_line] + [str_date] + [prod]
        data = str(line_sent)
        publish_message(producer, topic, 'parsed', data)
        sleep(10)
# Out:
# Publishing records..
# Message published successfully. Data:  ['-36.0856', '144.233', '11', '43.2', '5.9', '14', ' 0.00I', '100', '2019/01/01', 'Producer1']
# Message published successfully. Data:  ['-37.7052', '144.6926', '17', '52.7', '7.7', '14', ' 0.00G', '142', '2019/01/02', 'Producer1']
# Message published successfully. Data:  ['-36.837', '142.0391', '19', '55.8', '6', '11.1', ' 0.00I', '155', '2019/01/03', 'Producer1']
# Message published successfully. Data:  ['-37.189', '146.791', '21', '61.1', '6.6', '11.1', ' 0.00I', '163', '2019/01/04', 'Producer1']
# Message published successfully. Data:  ['-37.406', '148.088', '12', '43.9', '12', '15.9', ' 0.08G', '108', '2019/01/05', 'Producer1']
# Message published successfully. Data:  ['-36.1462', '145.2096', '10', '43.6', '9.7', '14', ' 0.20G', '90', '2019/01/06', 'Producer1']
# Message published successfully. Data:  ['-37.596', '149.319', '19', '56.1', '6.9', '12', ' 0.00A', '155', '2019/01/07', 'Producer1']
# Message published successfully. Data:  ['-37.425', '148.107', '15', '41.2', '13.8', '16.9', ' 0.00G', '138', '2019/01/08', 'Producer1']
# Message published successfully. Data:  ['-36.358', '143.113', '21', '58.8', '8.8', '22.9', ' 0.08G', '167', '2019/01/09', 'Producer1']
# Message published successfully. Data:  ['-36.8867', '142.1873', '14', '39.3', '17.7', '30.9', ' 0.01G', '131', '2019/01/10', 'Producer1']
# Message published successfully. Data:  ['-36.575', '146.6668', '18', '53.6', '7.9', '15.9', ' 0.00G', '150', '2019/01/11', 'Producer1']
# Message published successfully. Data:  ['-37.7052', '144.6926', '17', '52.7', '7.7', '14', ' 0.00G', '142', '2019/01/12', 'Producer1']
# Message published successfully. Data:  ['-37.608', '149.292', '15', '44.6', '9.7', '12', ' 0.02G', '134', '2019/01/13', 'Producer1']
# Message published successfully. Data:  ['-37.3583', '143.0203', '13', '43.3', '9.4', '14', ' 0.00G', '118', '2019/01/14', 'Producer1']
# Message published successfully. Data:  ['-37.95', '142.366', '16', '53.6', '8.1', '15', ' 0.00G', '133', '2019/01/15', 'Producer1']
# Message published successfully. Data:  ['-37.605', '149.326', '23', '49.6', '10', '19', ' 0.00I', '198', '2019/01/16', 'Producer1']
# Message published successfully. Data:  ['-37.864', '144.174', '28', '58.4', '11.9', '18.1', ' 0.04G', '223', '2019/01/17', 'Producer1']
# Message published successfully. Data:  ['-37.295', '144.377', '16', '54.8', '8.3', '9.9', ' 0.00G', '132', '2019/01/18', 'Producer1']
# Message published successfully. Data:  ['-37.461', '148.103', '10', '45.9', '3.2', '7', ' 0.00G', '89', '2019/01/19', 'Producer1']
# Message published successfully. Data:  ['-36.9194', '143.6131', '19', '50.3', '7.7', '11.1', ' 0.00I', '162', '2019/01/20', 'Producer1']
# Message published successfully. Data:  ['-37.863', '144.17', '18', '57.5', '16.1', '21', ' 0.00G', '145', '2019/01/21', 'Producer1']
# Message published successfully. Data:  ['-38.527', '143.493', '19', '51.5', '10.2', '20', ' 0.00I', '161', '2019/01/22', 'Producer1']
# Message published successfully. Data:  ['-37.33', '148.087', '12', '41.8', '14.7', '21', ' 0.00I', '110', '2019/01/23', 'Producer1']
# Message published successfully. Data:  ['-37.497', '147.266', '10', '41', '14.1', '20', ' 0.02G', '92', '2019/01/24', 'Producer1']
# Message published successfully. Data:  ['-34.282', '142.121', '15', '49.1', '9.6', '16.9', ' 0.01G', '130', '2019/01/25', 'Producer1']
# Message published successfully. Data:  ['-36.779', '146.108', '13', '42', '11.4', '16.9', ' 0.00G', '119', '2019/01/26', 'Producer1']
# Message published successfully. Data:  ['-37.635', '149.303', '24', '53.4', '9.9', '15.9', ' 0.00I', '200', '2019/01/27', 'Producer1']
# Message published successfully. Data:  ['-37.367', '148.04', '12', '47.6', '9.1', '13', ' 0.12G', '105', '2019/01/28', 'Producer1']
# Message published successfully. Data:  ['-36.575', '146.6668', '18', '53.6', '7.9', '15.9', ' 0.00G', '150', '2019/01/29', 'Producer1']
# Message published successfully. Data:  ['-36.0966', '142.3635', '22', '57', '8.5', '15', ' 0.00G', '178', '2019/01/30', 'Producer1']
# Message published successfully. Data:  ['-37.397', '148.121', '13', '44', '13.6', '21', ' 0.04G', '117', '2019/01/31', 'Producer1']
# Message published successfully. Data:  ['-36.4553', '142.8786', '19', '55.3', '6.2', '12', ' 0.00I', '156', '2019/02/01', 'Producer1']
# Message published successfully. Data:  ['-36.7685', '142.7134', '14', '48.2', '12.5', '19', ' 0.03G', '122', '2019/02/02', 'Producer1']
# Message published successfully. Data:  ['-36.3799', '143.7149', '12', '43.8', '6.7', '14', ' 0.16G', '108', '2019/02/03', 'Producer1']
# Message published successfully. Data:  ['-36.6859', '146.8907', '16', '51.5', '8.7', '15', ' 0.02G', '135', '2019/02/04', 'Producer1']
# Message published successfully. Data:  ['-38.167', '143.841', '21', '58.1', '5.3', '11.1', ' 0.00G', '168', '2019/02/05', 'Producer1']
# Message published successfully. Data:  ['-36.1', '143.767', '20', '53.5', '7.2', '15.9', ' 0.31G', '166', '2019/02/06', 'Producer1']
# Message published successfully. Data:  ['-35.889', '145.614', '14', '49.2', '10.5', '20', ' 0.12G', '121', '2019/02/07', 'Producer1']
# Message published successfully. Data:  ['-37.6662', '142.9874', '24', '51.9', '7.3', '13', ' 0.00I', '202', '2019/02/08', 'Producer1']
# Message published successfully. Data:  ['-37.062', '141.373', '26', '52.2', '13.7', '16.9', ' 0.00I', '219', '2019/02/09', 'Producer1']
# Message published successfully. Data:  ['-35.889', '145.614', '14', '49.2', '10.5', '20', ' 0.12G', '121', '2019/02/10', 'Producer1']
# Message published successfully. Data:  ['-37.627', '149.261', '26', '53.7', '8.7', '15', ' 0.00I', '216', '2019/02/11', 'Producer1']
# Message published successfully. Data:  ['-38.038', '142.986', '15', '50.7', '9.2', '13', ' 0.02G', '128', '2019/02/12', 'Producer1']
# Message published successfully. Data:  ['-35.961', '141.089', '5', '34.9', '4.3', '11.1', ' 0.00A', '48', '2019/02/13', 'Producer1']
# Message published successfully. Data:  ['-37.368', '148.05', '10', '41.4', '9.4', '14', ' 0.00I', '92', '2019/02/14', 'Producer1']
# Message published successfully. Data:  ['-37.227', '141.151', '9', '41.2', '10', '13', ' 0.02G', '83', '2019/02/15', 'Producer1']
# Message published successfully. Data:  ['-37.38', '148.053', '14', '51', '9.9', '15', ' 0.00I', '119', '2019/02/16', 'Producer1']
# Message published successfully. Data:  ['-37.437', '148.104', '12', '40.7', '16.7', '21', ' 0.12G', '111', '2019/02/17', 'Producer1']
# Message published successfully. Data:  ['-36.1858', '143.885', '20', '58.4', '4.7', '11.1', ' 0.01G', '159', '2019/02/18', 'Producer1']
# Message published successfully. Data:  ['-37.406', '148.088', '12', '43.9', '12', '15.9', ' 0.08G', '108', '2019/02/19', 'Producer1']
# Message published successfully. Data:  ['-37.477', '148.097', '8', '42.6', '2', '6', ' 0.00I', '73', '2019/02/20', 'Producer1']
# Message published successfully. Data:  ['-37.213', '142.941', '23', '61.9', '8', '15.9', ' 0.00I', '178', '2019/02/21', 'Producer1']
# Message published successfully. Data:  ['-37.0669', '141.0556', '12', '47.5', '15', '18.1', ' 0.20G', '105', '2019/02/22', 'Producer1']
# Message published successfully. Data:  ['-36.1', '143.767', '20', '53.5', '7.2', '15.9', ' 0.31G', '166', '2019/02/23', 'Producer1']
# Message published successfully. Data:  ['-37.945', '144.354', '24', '55.6', '5.9', '13', ' 0.00I', '196', '2019/02/24', 'Producer1']
# Message published successfully. Data:  ['-37.1815', '146.7777', '17', '50.4', '10.8', '16.9', ' 0.00I', '145', '2019/02/25', 'Producer1']
# Message published successfully. Data:  ['-37.633', '149.264', '16', '50.9', '12.9', '21', ' 0.03G', '136', '2019/02/26', 'Producer1']
# Message published successfully. Data:  ['-37.57', '148.034', '11', '40.4', '19.3', '26', ' 0.00G', '102', '2019/02/27', 'Producer1']
# Message published successfully. Data:  ['-37.461', '148.103', '10', '45.9', '3.2', '7', ' 0.00G', '89', '2019/02/28', 'Producer1']
# Message published successfully. Data:  ['-37.461', '148.109', '14', '50.7', '8.6', '13', ' 0.12G', '119', '2019/03/01', 'Producer1']
# Message published successfully. Data:  ['-37.608', '149.282', '22', '62.7', '7.6', '18.1', ' 0.00I', '169', '2019/03/02', 'Producer1']
# Message published successfully. Data:  ['-37.295', '144.377', '16', '54.8', '8.3', '9.9', ' 0.00G', '132', '2019/03/03', 'Producer1']
